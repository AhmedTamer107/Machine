# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:/Users/ahmed/Downloads/machine learning par/parctical/smoke_detection_iot.csv')

# %%
df
# Out:
#          num         UTC  Temperature  Humidity  TVOC  eCO2  Raw_H2  \
# 0          0  1654733331       20.000     57.36     0   400   12306
# 1          1  1654733332       20.015     56.67     0   400   12345
# 2          2  1654733333       20.029     55.96     0   400   12374
# 3          3  1654733334       20.044     55.28     0   400   12390
# 4          4  1654733335       20.059     54.69     0   400   12403
# ...      ...         ...          ...       ...   ...   ...     ...
# 62625  62625  1655130047       18.438     15.79   625   400   13723
# 62626  62626  1655130048       18.653     15.87   612   400   13731
# 62627  62627  1655130049       18.867     15.84   627   400   13725
# 62628  62628  1655130050       19.083     16.04   638   400   13712
# 62629  62629  1655130051       19.299     16.52   643   400   13696
#
#        Raw_Ethanol  Pressure   PM1   PM2   NC0    NC1    NC2   CNT  Fire_Alarm
# ...

# %%
df['Fire_Alarm'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.isnull().sum()
# Out:
# num            0
# UTC            0
# Temperature    0
# Humidity       0
# TVOC           0
# eCO2           0
# Raw_H2         0
# Raw_Ethanol    0
# Pressure       0
# PM1            0
# PM2            0
# NC0            0
# NC1            0
# NC2            0
# CNT            0
# Fire_Alarm     0
# dtype: int64

# %%
df.Fire_Alarm.value_counts(dropna=False)
# Out:
# 1    44757
# 0    17873
# Name: Fire_Alarm, dtype: int64

# %%
counts=df.Fire_Alarm.value_counts(dropna=False)

# %%
df.pivot_table(index=['Fire_Alarm'], aggfunc=np.sum)
# Out:
#                   CNT    Humidity          NC0          NC1          NC2  \
# Fire_Alarm
# 0            43084812   767289.26  24240860.64  8826974.730  3198949.911
# 1           615243303  2272739.59   6539505.11  3923646.982  1814521.610
#
#                    PM1         PM2      Pressure  Raw_Ethanol     Raw_H2  \
# Fire_Alarm
# 0           4682416.90  8043469.10  1.676669e+07    358940305  230495871
# 1           1617804.68  3509747.35  4.201956e+07    878268868  580090019
#
#                 TVOC  Temperature             UTC      eCO2         num
# Fire_Alarm
# 0           82154804   352005.215  29577310112239  17204322   744462124
# 1           39476259   648222.414  74062316992882  24759096  1216765011

# %%
counts = df['Fire_Alarm'].value_counts()
colors = ['orange', 'lavender']

counts = counts.sort_index(ascending=True)
wedgeprops = {'linewidth': 1, 'edgecolor': 'black'}
plt.pie(counts, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90, wedgeprops=wedgeprops)


plt.title("Fire Alarm graph", color='grey', loc='left', fontweight='1', fontsize=8)

plt.legend(labels, loc="upper right")

plt.show()
